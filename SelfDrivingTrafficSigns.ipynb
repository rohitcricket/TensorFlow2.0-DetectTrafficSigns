# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitcricket/TensorFlow2.0-DetectTrafficSigns/blob/master/SelfDrivingTrafficSigns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Self Driving Traffic Signs Detection**

# %% [markdown]
# In this case study, you have been provided with images of traffic signs and the goal is to train a Deep Network to classify them
# The dataset contains 43 different classes of images.
# Classes are as listed below:
#
# ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
# ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
# (4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
# ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
# ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
# (10, b'No passing for vehicles over 3.5 metric tons')
# (11, b'Right-of-way at the next intersection') (12, b'Priority road')
# (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
# (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
# (18, b'General caution') (19, b'Dangerous curve to the left')
# (20, b'Dangerous curve to the right') (21, b'Double curve')
# (22, b'Bumpy road') (23, b'Slippery road')
# (24, b'Road narrows on the right') (25, b'Road work')
# (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
# (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
# (31, b'Wild animals crossing')
# (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
# (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
# (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
# (40, b'Roundabout mandatory') (41, b'End of no passing')
# (42, b'End of no passing by vehicles over 3.5 metric tons')
# The network used is called LeNet that was presented by Yann LeCun http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf
#
# Citation J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011. @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %% [markdown]
# ### **Step 1: Import Libraries**

# %%
# !pip install tensorflow-gpu==2.0.0
# Out:
# Collecting tensorflow-gpu==2.0.0
#   Downloading https://files.pythonhosted.org/packages/25/44/47f0722aea081697143fbcf5d2aa60d1aee4aaacb5869aee2b568974777b/tensorflow_gpu-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (380.8MB)
#      |████████████████████████████████| 380.8MB 55kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.16.5)
# Collecting tensorboard<2.1.0,>=2.0.0 (from tensorflow-gpu==2.0.0)
#   Downloading https://files.pythonhosted.org/packages/9b/a6/e8ffa4e2ddb216449d34cfcb825ebb38206bee5c4553d69e7bc8bc2c5d64/tensorboard-2.0.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 34.1MB/s
# Collecting tensorflow-estimator<2.1.0,>=2.0.0 (from tensorflow-gpu==2.0.0)
#   Downloading https://files.pythonhosted.org/packages/95/00/5e6cdf86190a70d7382d320b2b04e4ff0f8191a37d90a422a2f8ff0705bb/tensorflow_estimator-2.0.0-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 59.6MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.8.0)
# Collecting gast==0.2.2 (from tensorflow-gpu==2.0.0)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (3.7.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (3.0.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.11.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.33.6)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.1.7)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (41.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.0.0) (2.8.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=5df05a27b3650200613fb877d3ab26b1a147ab7290f591230a2accfba258ea3f
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 1.14.0 has requirement tensorboard<1.15.0,>=1.14.0, but you'll have tensorboard 2.0.0 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement tensorflow-estimator<1.15.0rc0,>=1.14.0rc0, but you'll have tensorflow-estimator 2.0.0 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, gast, tensorflow-gpu
#   Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Found existing installation: gast 0.3.2
#     Uninstalling gast-0.3.2:
#       Successfully uninstalled gast-0.3.2
# Successfully installed gast-0.2.2 tensorboard-2.0.0 tensorflow-estimator-2.0.0 tensorflow-gpu-2.0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle

# %% [markdown]
# ### **Step 2: Input Data and Normalize**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
with open("/content/drive/My Drive/Colab Notebooks/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/drive/My Drive/Colab Notebooks/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/drive/My Drive/Colab Notebooks/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# ### **Step 3: Visualize the Data**

# %%
# Let's take a random number, say, 3100
i = 3100
plt.imshow(X_train[i])
y_train[i]
# Out:
# 1

# %% [markdown]
# Data set returns '1' which is 30. So we got it right.

# %%
i = 3001
plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 7

# %% [markdown]
# Data set returns '7' which is 100. So we got it right.

# %%
i = 2100
plt.imshow(X_test[i])
y_test[i]
# Out:
# 29

# %% [markdown]
# ### **Step 4: Data Preparation**

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# Grayscale the data!

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %% [markdown]
# Normalize the Data

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[-0.84114583],
#          [-0.828125  ],
#          [-0.7734375 ],
#          ...,
#          [-0.81510417],
#          [-0.83333333],
#          [-0.8515625 ]],
#
#         [[-0.859375  ],
#          [-0.84375   ],
#          [-0.8203125 ],
#          ...,
#          [-0.83072917],
#          [-0.8203125 ],
#          [-0.81510417]],
#
#         [[-0.83854167],
#          [-0.80729167],
#          [-0.83854167],
#          ...,
#          [-0.76822917],
#          [-0.76302083],
#          [-0.79947917]],
#
#         ...,
#
#         [[-0.51041667],
#          [-0.55208333],
#          [-0.65364583],
#          ...,
#          [-0.8671875 ],
#          [-0.81770833],
#          [-0.70052083]],
#
#         [[-0.61197917],
#          [-0.55208333],
#          [-0.08072917],
#          ...,
#          [-0.82552083],
#          [-0.77864583],
#          [-0.76041667]],
#
#         [[-0.4609375 ],
#          [-0.46354167],
#          [ 0.01302083],
#          ...,
#          [-0.58072917],
#          [-0.7265625 ],
#          [-0.77864583]]],
#
#
#        [[[-0.80989583],
#          [-0.8046875 ],
#          [-0.80208333],
#          ...,
#          [-0.828125  ],
#          [-0.86197917],
#          [-0.8671875 ]],
#
#         [[-0.8046875 ],
#          [-0.80729167],
#          [-0.79947917],
#          ...,
#          [-0.82552083],
#          [-0.86458333],
#          [-0.8671875 ]],
#
#         [[-0.79166667],
#          [-0.7890625 ],
#          [-0.7890625 ],
#          ...,
#          [-0.828125  ],
#          [-0.859375  ],
#          [-0.86979167]],
#
#         ...,
#
#         [[-0.8984375 ],
#          [-0.84114583],
#          [-0.61197917],
#          ...,
#          [-0.6328125 ],
#          [-0.65104167],
#          [-0.65625   ]],
#
#         [[-0.86979167],
#          [-0.81510417],
#          [-0.640625  ],
#          ...,
#          [-0.77083333],
#          [-0.640625  ],
#          [-0.484375  ]],
#
#         [[-0.82552083],
#          [-0.79427083],
#          [-0.77083333],
#          ...,
#          [-0.84114583],
#          [-0.80208333],
#          [-0.765625  ]]],
#
#
#        [[[-0.79427083],
#          [-0.75260417],
#          [-0.67708333],
#          ...,
#          [ 0.01302083],
#          [ 0.02864583],
#          [ 0.04947917]],
#
#         [[-0.80729167],
#          [-0.75      ],
#          [-0.68229167],
#          ...,
#          [ 0.0234375 ],
#          [ 0.01041667],
#          [ 0.02083333]],
#
#         [[-0.796875  ],
#          [-0.76041667],
#          [-0.72916667],
#          ...,
#          [ 0.04427083],
#          [ 0.0234375 ],
#          [ 0.02604167]],
#
#         ...,
#
#         [[-0.8828125 ],
#          [-0.88020833],
#          [-0.87760417],
#          ...,
#          [-0.76822917],
#          [-0.73958333],
#          [-0.66927083]],
#
#         [[-0.88541667],
#          [-0.88541667],
#          [-0.88541667],
#          ...,
#          [-0.78385417],
#          [-0.76302083],
#          [-0.6796875 ]],
#
#         [[-0.88541667],
#          [-0.88802083],
#          [-0.8828125 ],
#          ...,
#          [-0.8125    ],
#          [-0.79166667],
#          [-0.734375  ]]],
#
#
#        ...,
#
#
#        [[[ 0.32552083],
#          [ 0.3203125 ],
#          [ 0.11197917],
#          ...,
#          [ 0.06510417],
#          [-0.17708333],
#          [-0.35677083]],
#
#         [[ 0.3046875 ],
#          [ 0.17708333],
#          [ 0.09635417],
#          ...,
#          [-0.23958333],
#          [-0.39583333],
#          [-0.4453125 ]],
#
#         [[ 0.2265625 ],
#          [ 0.109375  ],
#          [ 0.18229167],
#          ...,
#          [-0.46614583],
#          [-0.5       ],
#          [-0.47135417]],
#
#         ...,
#
#         [[-0.1484375 ],
#          [-0.19270833],
#          [-0.21614583],
#          ...,
#          [ 0.06770833],
#          [ 0.13020833],
#          [ 0.265625  ]],
#
#         [[-0.2734375 ],
#          [-0.16927083],
#          [-0.04947917],
#          ...,
#          [ 0.43489583],
#          [ 0.390625  ],
#          [ 0.32291667]],
#
#         [[-0.52604167],
#          [-0.38020833],
#          [ 0.046875  ],
#          ...,
#          [ 0.47395833],
#          [ 0.37760417],
#          [ 0.2734375 ]]],
#
#
#        [[[-0.50520833],
#          [-0.48697917],
#          [-0.52864583],
#          ...,
#          [-0.51822917],
#          [-0.5625    ],
#          [-0.5703125 ]],
#
#         [[-0.50260417],
#          [-0.51302083],
#          [-0.54947917],
#          ...,
#          [-0.52864583],
#          [-0.5546875 ],
#          [-0.5546875 ]],
#
#         [[-0.5       ],
#          [-0.55989583],
#          [-0.59895833],
#          ...,
#          [-0.54947917],
#          [-0.54947917],
#          [-0.53645833]],
#
#         ...,
#
#         [[-0.38802083],
#          [-0.421875  ],
#          [-0.44270833],
#          ...,
#          [-0.59895833],
#          [-0.59635417],
#          [-0.60416667]],
#
#         [[-0.421875  ],
#          [-0.43229167],
#          [-0.421875  ],
#          ...,
#          [-0.55208333],
#          [-0.52864583],
#          [-0.5546875 ]],
#
#         [[-0.46354167],
#          [-0.45833333],
#          [-0.4609375 ],
#          ...,
#          [-0.55729167],
#          [-0.56510417],
#          [-0.5859375 ]]],
#
#
#        [[[-0.87760417],
#          [-0.87239583],
#          [-0.87760417],
#          ...,
#          [-0.84375   ],
#          [-0.85416667],
#          [-0.8515625 ]],
#
#         [[-0.87760417],
#          [-0.8828125 ],
#          [-0.88541667],
#          ...,
#          [-0.8515625 ],
#          [-0.84114583],
#          [-0.83072917]],
#
#         [[-0.88020833],
#          [-0.87760417],
#          [-0.875     ],
#          ...,
#          [-0.828125  ],
#          [-0.828125  ],
#          [-0.8515625 ]],
#
#         ...,
#
#         [[-0.86458333],
#          [-0.84895833],
#          [-0.84635417],
#          ...,
#          [-0.88020833],
#          [-0.87760417],
#          [-0.8671875 ]],
#
#         [[-0.86197917],
#          [-0.859375  ],
#          [-0.86197917],
#          ...,
#          [-0.89322917],
#          [-0.87760417],
#          [-0.85677083]],
#
#         [[-0.84114583],
#          [-0.84895833],
#          [-0.859375  ],
#          ...,
#          [-0.88541667],
#          [-0.86458333],
#          [-0.8359375 ]]]])

# %%
i = 60
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %%
i = 610
plt.imshow(X_test_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_test[i])
plt.figure()
plt.imshow(X_test_gray_norm[i].squeeze(), cmap = 'gray')

# %%
i = 500
plt.imshow(X_validation_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_validation[i])
plt.figure()
plt.imshow(X_validation_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# ### **Step 5: Train the Model**

# %% [markdown]
# The model consists of the following layers:
#
# STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
# Input = 32x32x1
# Output = 28x28x6
# Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
# Used a 5x5 Filter with input depth of 3 and output depth of 6
# Apply a RELU Activation function to the output
# pooling for input, Input = 28x28x6 and Output = 14x14x6
# * Stride is the amount by which the kernel is shifted when the kernel is passed over the image.
# STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#
# Input = 14x14x6
# Output = 10x10x16
# Layer 2: Convolutional layer with Output = 10x10x16
# Output = (Input-filter+1)/strides => 10 = 14-5+1/1
# Apply a RELU Activation function to the output
# Pooling with Input = 10x10x16 and Output = 5x5x16
# STEP 3: FLATTENING THE NETWORK
#
# Flatten the network with Input = 5x5x16 and Output = 400
# STEP 4: FULLY CONNECTED LAYER
#
# Layer 3: Fully Connected layer with Input = 400 and Output = 120
# Apply a RELU Activation function to the output
# STEP 5: ANOTHER FULLY CONNECTED LAYER
#
# Layer 4: Fully Connected Layer with Input = 120 and Output = 84
# Apply a RELU Activation function to the output
# STEP 6: FULLY CONNECTED LAYER
#
# Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from tensorflow.keras import datasets, layers, models

LeNet = models.Sequential()

LeNet.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (32,32,1)))
LeNet.add(layers.AveragePooling2D())


LeNet.add(layers.Conv2D(16, (5,5), activation = 'relu'))
LeNet.add(layers.AveragePooling2D())

LeNet.add(layers.Flatten())

LeNet.add(layers.Dense(120, activation = 'relu'))

LeNet.add(layers.Dense(84, activation = 'relu'))

LeNet.add(layers.Dense(43, activation = 'softmax'))
LeNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = LeNet.fit(X_train_gray_norm,
                 y_train, 
                 batch_size = 500,
                 nb_epoch = 50,
                 verbose = 1,
                 validation_data = (X_validation_gray_norm, y_validation))
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 17s 498us/sample - loss: 3.0894 - accuracy: 0.1956 - val_loss: 2.4517 - val_accuracy: 0.3642
# Epoch 2/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 1.4530 - accuracy: 0.5973 - val_loss: 1.1678 - val_accuracy: 0.6567
# Epoch 3/50
# 34799/34799 [==============================] - 17s 475us/sample - loss: 0.7717 - accuracy: 0.7832 - val_loss: 0.8406 - val_accuracy: 0.7401
# Epoch 4/50
# 34799/34799 [==============================] - 17s 476us/sample - loss: 0.5415 - accuracy: 0.8538 - val_loss: 0.7365 - val_accuracy: 0.7880
# Epoch 5/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.4286 - accuracy: 0.8868 - val_loss: 0.6278 - val_accuracy: 0.8259
# Epoch 6/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 0.3592 - accuracy: 0.9068 - val_loss: 0.5733 - val_accuracy: 0.8388
# Epoch 7/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.3115 - accuracy: 0.9202 - val_loss: 0.5848 - val_accuracy: 0.8483
# Epoch 8/50
# 34799/34799 [==============================] - 17s 475us/sample - loss: 0.2704 - accuracy: 0.9314 - val_loss: 0.5623 - val_accuracy: 0.8467
# Epoch 9/50
# 34799/34799 [==============================] - 17s 476us/sample - loss: 0.2348 - accuracy: 0.9424 - val_loss: 0.5490 - val_accuracy: 0.8592
# Epoch 10/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.2115 - accuracy: 0.9475 - val_loss: 0.5178 - val_accuracy: 0.8608
# Epoch 11/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.1938 - accuracy: 0.9518 - val_loss: 0.5317 - val_accuracy: 0.8537
# Epoch 12/50
# 34799/34799 [==============================] - 17s 475us/sample - loss: 0.1740 - accuracy: 0.9572 - val_loss: 0.5269 - val_accuracy: 0.8610
# Epoch 13/50
# 34799/34799 [==============================] - 17s 475us/sample - loss: 0.1566 - accuracy: 0.9618 - val_loss: 0.5046 - val_accuracy: 0.8680
# Epoch 14/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.1436 - accuracy: 0.9653 - val_loss: 0.5253 - val_accuracy: 0.8703
# Epoch 15/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 0.1316 - accuracy: 0.9681 - val_loss: 0.4996 - val_accuracy: 0.8735
# Epoch 16/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.1182 - accuracy: 0.9710 - val_loss: 0.5048 - val_accuracy: 0.8837
# Epoch 17/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.1064 - accuracy: 0.9754 - val_loss: 0.5135 - val_accuracy: 0.8755
# Epoch 18/50
# 34799/34799 [==============================] - 17s 481us/sample - loss: 0.0976 - accuracy: 0.9769 - val_loss: 0.5268 - val_accuracy: 0.8757
# Epoch 19/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.0926 - accuracy: 0.9769 - val_loss: 0.5487 - val_accuracy: 0.8762
# Epoch 20/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0887 - accuracy: 0.9781 - val_loss: 0.5089 - val_accuracy: 0.8984
# Epoch 21/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 0.0809 - accuracy: 0.9807 - val_loss: 0.5308 - val_accuracy: 0.8714
# Epoch 22/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.0741 - accuracy: 0.9820 - val_loss: 0.5280 - val_accuracy: 0.8807
# Epoch 23/50
# 34799/34799 [==============================] - 17s 477us/sample - loss: 0.0681 - accuracy: 0.9840 - val_loss: 0.5552 - val_accuracy: 0.8755
# Epoch 24/50
# 34799/34799 [==============================] - 17s 484us/sample - loss: 0.0631 - accuracy: 0.9853 - val_loss: 0.5348 - val_accuracy: 0.8841
# Epoch 25/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.0588 - accuracy: 0.9862 - val_loss: 0.5503 - val_accuracy: 0.8848
# Epoch 26/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0559 - accuracy: 0.9872 - val_loss: 0.5155 - val_accuracy: 0.8909
# Epoch 27/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 0.0499 - accuracy: 0.9887 - val_loss: 0.5307 - val_accuracy: 0.8921
# Epoch 28/50
# 34799/34799 [==============================] - 17s 483us/sample - loss: 0.0477 - accuracy: 0.9884 - val_loss: 0.5317 - val_accuracy: 0.8918
# Epoch 29/50
# 34799/34799 [==============================] - 17s 481us/sample - loss: 0.0464 - accuracy: 0.9892 - val_loss: 0.5277 - val_accuracy: 0.8927
# Epoch 30/50
# 34799/34799 [==============================] - 17s 482us/sample - loss: 0.0406 - accuracy: 0.9903 - val_loss: 0.6086 - val_accuracy: 0.8900
# Epoch 31/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.0375 - accuracy: 0.9916 - val_loss: 0.5940 - val_accuracy: 0.8887
# Epoch 32/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0356 - accuracy: 0.9916 - val_loss: 0.5750 - val_accuracy: 0.8939
# Epoch 33/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0445 - accuracy: 0.9884 - val_loss: 0.6313 - val_accuracy: 0.8800
# Epoch 34/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.0341 - accuracy: 0.9913 - val_loss: 0.6199 - val_accuracy: 0.8830
# Epoch 35/50
# 34799/34799 [==============================] - 17s 481us/sample - loss: 0.0290 - accuracy: 0.9937 - val_loss: 0.6252 - val_accuracy: 0.8896
# Epoch 36/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 0.0266 - accuracy: 0.9941 - val_loss: 0.5772 - val_accuracy: 0.8927
# Epoch 37/50
# 34799/34799 [==============================] - 17s 483us/sample - loss: 0.0306 - accuracy: 0.9920 - val_loss: 0.6376 - val_accuracy: 0.8837
# Epoch 38/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.0243 - accuracy: 0.9946 - val_loss: 0.6156 - val_accuracy: 0.8930
# Epoch 39/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0213 - accuracy: 0.9955 - val_loss: 0.5727 - val_accuracy: 0.9009
# Epoch 40/50
# 34799/34799 [==============================] - 17s 475us/sample - loss: 0.0206 - accuracy: 0.9957 - val_loss: 0.6505 - val_accuracy: 0.8866
# Epoch 41/50
# 34799/34799 [==============================] - 17s 482us/sample - loss: 0.0183 - accuracy: 0.9961 - val_loss: 0.6469 - val_accuracy: 0.8923
# Epoch 42/50
# 34799/34799 [==============================] - 17s 482us/sample - loss: 0.0186 - accuracy: 0.9958 - val_loss: 0.6702 - val_accuracy: 0.8957
# Epoch 43/50
# 34799/34799 [==============================] - 17s 478us/sample - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.6575 - val_accuracy: 0.8907
# Epoch 44/50
# 34799/34799 [==============================] - 17s 479us/sample - loss: 0.0254 - accuracy: 0.9930 - val_loss: 0.6304 - val_accuracy: 0.8905
# Epoch 45/50
# 34799/34799 [==============================] - 17s 483us/sample - loss: 0.0237 - accuracy: 0.9939 - val_loss: 0.6740 - val_accuracy: 0.8855
# Epoch 46/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0180 - accuracy: 0.9954 - val_loss: 0.6942 - val_accuracy: 0.8937
# Epoch 47/50
# 34799/34799 [==============================] - 17s 484us/sample - loss: 0.0141 - accuracy: 0.9967 - val_loss: 0.6431 - val_accuracy: 0.8961
# Epoch 48/50
# 34799/34799 [==============================] - 17s 480us/sample - loss: 0.0123 - accuracy: 0.9973 - val_loss: 0.6776 - val_accuracy: 0.8937
# Epoch 49/50
# 34799/34799 [==============================] - 17s 482us/sample - loss: 0.0106 - accuracy: 0.9978 - val_loss: 0.6986 - val_accuracy: 0.8923
# Epoch 50/50
# 34799/34799 [==============================] - 17s 476us/sample - loss: 0.0099 - accuracy: 0.9978 - val_loss: 0.6592 - val_accuracy: 0.9039

# %% [markdown]
# ### **Step 6: Model Evaluation**

# %%
score = LeNet.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test Accuracy: 0.8832937479019165

# %% [markdown]
# We got 88% accuracy with the test data

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %% [markdown]
# The model is losing generalization! We have to stop it earlier, i.e., less epochs.

# %%
predicted_classes = LeNet.predict_classes(X_test_gray_norm)
y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %% [markdown]
# Mostly good! We see only a few samples misclassified!

# %%
L = 7
W = 7

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# Mostly good, and only a few are difficult to classify!
